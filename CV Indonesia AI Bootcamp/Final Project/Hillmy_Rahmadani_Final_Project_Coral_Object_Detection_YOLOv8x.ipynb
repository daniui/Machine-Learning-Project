# %% [markdown]
# <a align="center" href="https://hub.ultralytics.com" target="_blank">
# <img width="1024", src="https://github.com/ultralytics/assets/raw/main/im/ultralytics-hub.png"></a>
#
# <div align="center">
#
# [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [हिन्दी](https://docs.ultralytics.com/hi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/hub/actions/workflows/ci.yaml">
#     <img src="https://github.com/ultralytics/hub/actions/workflows/ci.yaml/badge.svg" alt="CI CPU"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/hub/blob/master/hub.ipynb">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
# Welcome to the [Ultralytics](https://ultralytics.com/) HUB notebook!
#
# This notebook allows you to train [YOLOv5](https://github.com/ultralytics/yolov5) and [YOLOv8](https://github.com/ultralytics/ultralytics) 🚀 models using [HUB](https://hub.ultralytics.com/). Please browse the HUB <a href="https://docs.ultralytics.com/hub/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/hub/issues/new/choose">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.

# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub
checks()  # checks
# Out:
# Ultralytics YOLOv8.1.10 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
hub.login('62ae6253113deb349ae295ccbcfd968eda95442486')

model = YOLO('https://hub.ultralytics.com/models/XSKkKHOMfOIPgDcTBPPs')
results = model.train()
# Out:
# requirements: Ultralytics requirement ['hub-sdk>=0.0.2'] not found, attempting AutoUpdate...
# ...
#
# requirements: AutoUpdate success ✅ 6.3s, installed 1 package: ['hub-sdk>=0.0.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/XSKkKHOMfOIPgDcTBPPs 🚀
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 334MB/s]
# Ultralytics YOLOv8.1.10 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import json
import requests

# Run inference on an image
url = "https://api.ultralytics.com/v1/predict/9WkmA6ixcrTrcMpsBHrZ"
headers = {"x-api-key": "62ae6253113deb349ae295ccbcfd968eda95442486"}
data = {"size": 640, "confidence": 0.25, "iou": 0.45}
with open("/content/datasets/NrM8n12co5/test/images/LINIFoundation-ABZU-coralforms-latc-11_jpg.rf.8fef76a686252cfb50ad9822d7e0785d.jpg", "rb") as f:
	response = requests.post(url, headers=headers, data=data, files={"image": f})

# Check for successful response
response.raise_for_status()

# Print inference results
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "data": [
#     {
#       "class": 6,
#       "confidence": 0.948149561882019,
#       "height": 0.23781777918338776,
#       "name": "Tabulate",
#       "width": 0.10167589038610458,
#       "xcenter": 0.7025585174560547,
#       "ycenter": 0.7202820777893066
#     },
#     {
#       "class": 0,
#       "confidence": 0.9308158159255981,
#       "height": 0.2598753273487091,
#       "name": "Branching",
#       "width": 0.18699702620506287,
#       "xcenter": 0.7285544276237488,
#       "ycenter": 0.47171324491500854
#     },
#     {
#       "class": 6,
#       "confidence": 0.8375453352928162,
#       "height": 0.17367586493492126,
#       "name": "Tabulate",
#       "width": 0.0923471450805664,
#       "xcenter": 0.6227900385856628,
#       "ycenter": 0.5107696652412415
#     }
#   ],
#   "message": "Inference complete.",
#   "success": true
# }

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# UTF-8

# %%
# %ls /content/runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
#validation
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/datasets/NrM8n12co5/data.yaml
# Out:
# Ultralytics YOLOv8.1.10 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/datasets/NrM8n12co5/valid/labels.cache... 33 images, 0 backgrounds, 0 corrupt: 100% 33/33 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.42s/it]
#                    all         33        316      0.744      0.722      0.782       0.57
#              Branching         33         93      0.856      0.742       0.86      0.591
#             Encrusting         33         50      0.781       0.76      0.788      0.546
#                Foliose         33         11      0.553      0.636      0.597       0.47
#                Massive         33         73      0.705      0.644      0.762      0.499
#               Mushroom         33         40      0.828      0.843      0.867      0.658
# ...

# %%
print(1)

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train/weights/best.pt')

# %%
model.predict(source='/content/datasets/NrM8n12co5/valid/images/LINIFoundation-ABZU-coralforms-latc-10_jpg.rf.74f2a478d07ae7bda27bf2d356d1677b.jpg',imgsz=640,conf=0.6,save=True)
# Out:
# image 1/1 /content/datasets/NrM8n12co5/valid/images/LINIFoundation-ABZU-coralforms-latc-10_jpg.rf.74f2a478d07ae7bda27bf2d356d1677b.jpg: 384x640 1 Branching, 3 Tabulates, 112.2ms
# Speed: 3.2ms preprocess, 112.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Branching', 1: 'Encrusting', 2: 'Foliose', 3: 'Massive', 4: 'Mushroom', 5: 'Submassive', 6: 'Tabulate'}
#  obb: None
#  orig_img: array([[[222, 182,   0],
#          [223, 183,   1],
#          [223, 183,   1],
#          ...,
#          [223, 179,   2],
#          [221, 177,   0],
#          [221, 177,   0]],
#
#         [[222, 182,   0],
#          [222, 182,   0],
#          [223, 183,   1],
#          ...,
#          [223, 179,   2],
#          [221, 177,   0],
#          [221, 177,   0]],
#
# ...

# %%
# print out the test prediction
print("Test Predict:")
Image(filename='/content/runs/detect/predict/LINIFoundation-ABZU-coralforms-latc-10_jpg.rf.74f2a478d07ae7bda27bf2d356d1677b.jpg', width=900)
# Out:
# Test Predict:

# %%
model.predict(source='/content/datasets/NrM8n12co5/valid/images/LINIFoundation-ABZU-coralforms-latc-23_jpg.rf.5ed977ca2e09bafed897992cccf8f22b.jpg',imgsz=640,conf=0.6,save=True)
print("Test Predict:")
Image(filename='/content/runs/detect/predict/LINIFoundation-ABZU-coralforms-latc-23_jpg.rf.5ed977ca2e09bafed897992cccf8f22b.jpg', width=900)
# Out:
# image 1/1 /content/datasets/NrM8n12co5/valid/images/LINIFoundation-ABZU-coralforms-latc-23_jpg.rf.5ed977ca2e09bafed897992cccf8f22b.jpg: 384x640 2 Branchings, 1 Encrusting, 4 Massives, 62.2ms
# Speed: 3.6ms preprocess, 62.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# Test Predict:

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.predict('/content/drive/MyDrive/indonesia_ai/Final_Project/video/raw-video.mp4', save=True, conf=0.5, stream = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1800) /content/drive/MyDrive/indonesia_ai/Final_Project/video/raw-video.mp4: 384x640 1 Massive, 3 Tabulates, 62.2ms
# video 1/1 (2/1800) /content/drive/MyDrive/indonesia_ai/Final_Project/video/raw-video.mp4: 384x640 1 Massive, 3 Tabulates, 62.0ms
# video 1/1 (3/1800) /content/drive/MyDrive/indonesia_ai/Final_Project/video/raw-video.mp4: 384x640 1 Massive, 3 Tabulates, 62.3ms
# ...

# %%
from IPython.display import Image, clear_output
Image(filename = "/content/runs/detect/train/confusion_matrix.png")

# %%
Image(filename = "/content/runs/detect/train/confusion_matrix_normalized.png")

# %%
Image(filename = "/content/runs/detect/train/results.png")

# %% [markdown]
# # Start
#
# Login with your [API key](https://hub.ultralytics.com/settings?tab=api+keys), select your YOLO 🚀 model and start training!

# %%
hub.login('API_KEY')  # use your API key

model = YOLO('https://hub.ultralytics.com/MODEL_ID')  # use your model URL
results = model.train()  # train model
